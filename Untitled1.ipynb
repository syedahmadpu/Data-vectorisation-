# %%
import numpy as np
import pandas as pd
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
from string import punctuation, digits
from IPython.core.display import display, HTML
from nltk.corpus import stopwords
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
import gensim.models.keyedvectors as word2vec #need to use due to depreceated model
from nltk.tokenize import RegexpTokenizer

# %%
#Amazon Data
input_file = "Round1_Problem1-of-2_Dataset_amazon_cells_labelled.txt"
amazon = pd.read_csv(input_file,delimiter='\t',header=None)
amazon.columns = ['Text','Sentiment']

#Imdb Data
input_file = "Round1_Problem1-of-2_Dataset_imdb_labelled.txt"
imdb = pd.read_csv(input_file,delimiter='\t',header=None)
imdb.columns = ['Text','Sentiment']

# %%
#combine all data sets
data = pd.DataFrame()
data = pd.concat([amazon, imdb])
data['index'] = data.index

# %%
data.shape
# Out:
# (1748, 3)

# %%
data.head()
# Out:
#                                                 Text  Sentiment  index
# 0  So there is no way for me to plug it in here i...          0      0
# 1                        Good case, Excellent value.          1      1
# 2                             Great for the jawbone.          1      2
# 3  Tied to charger for conversations lasting more...          0      3
# 4                                  The mic is great.          1      4

# %%
#Text Preprocessing
columns = ['index','Sentiment', 'Text']
df_ = pd.DataFrame(columns=columns)

# %%
df_
# Out:
# Empty DataFrame
# Columns: [index, Sentiment, Text]
# Index: []

# %%
#lower string
data['Text'] = data['Text'].str.lower()
data.head()
# Out:
#                                                 Text  Sentiment  index
# 0  so there is no way for me to plug it in here i...          0      0
# 1                        good case, excellent value.          1      1
# 2                             great for the jawbone.          1      2
# 3  tied to charger for conversations lasting more...          0      3
# 4                                  the mic is great.          1      4

# %%
#remove email adress
data['Text'] = data['Text'].replace('[a-zA-Z0-9-_.]+@[a-zA-Z0-9-_.]+', '', regex=True)
data.head()
# Out:
#                                                 Text  Sentiment  index
# 0  so there is no way for me to plug it in here i...          0      0
# 1                        good case, excellent value.          1      1
# 2                             great for the jawbone.          1      2
# 3  tied to charger for conversations lasting more...          0      3
# 4                                  the mic is great.          1      4

# %%
#Remove all website links from the data of for www.xyz.com
data['Text'] = data['Text'].replace(r'http\S+', '', regex=True).replace(r'www\S+', '', regex=True)
data.head()
# Out:
#                                                 Text  Sentiment  index
# 0  so there is no way for me to plug it in here i...          0      0
# 1                        good case, excellent value.          1      1
# 2                             great for the jawbone.          1      2
# 3  tied to charger for conversations lasting more...          0      3
# 4                                  the mic is great.          1      4

# %%
#Convert major emoticons to their respective emotions
#data["Text"].replace(':)', 'happy',regex=True).replace(':(r','sad', regex=True).replace(r':D', 'laugh', regex=True)
#data.head()
data['Text'] = data['Text'].replace('\U0001f600', 'happy', regex = True).replace
data.head()
# Out:
#                                                 Text  Sentiment  index
# 0  <bound method Series.replace of 0      so ther...          0      0
# 1  <bound method Series.replace of 0      so ther...          1      1
# 2  <bound method Series.replace of 0      so ther...          1      2
# 3  <bound method Series.replace of 0      so ther...          0      3
# 4  <bound method Series.replace of 0      so ther...          1      4

# %%
#remove punctaitions and special chracters
data['Text'] = data['Text'].str.replace('[^\w\s]','')

# %%
#remove numbers
data['Text'] = data['Text'].replace('\d', '', regex=True)

# %%
#Remove major stopwords.
for index, row in data.iterrows():
    word_tokens = word_tokenize(row['Text'])
    filtered_sentence = [w for w in word_tokens if not w in stopwords.words('english')]
    df_ = df_.append({"index": row['index'], "Sentiment":  row['Sentiment'],"Text": " ".join(filtered_sentence[0:])}, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-85c434965eaf> in <module>()
#       1 #Remove major stopwords.
#       2 for index, row in data.iterrows():
# ----> 3     word_tokens = word_tokenize(row['Text'])
#       4     filtered_sentence = [w for w in word_tokens if not w in stopwords.words('english')]
#       5     df_ = df_.append({"index": row['index'], "Sentiment":  row['Sentiment'],"Text": " ".join(filtered_sentence[0:])}, ignore_index=True)
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     126     :type preserver_line: bool
#     127     """
# --> 128     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     129     return [token for sent in sentences
#     130             for token in _treebank_word_tokenizer.tokenize(sent)]
#
# ...

# %%
data.head(20)
# Out:
#     Text  Sentiment  index
# 0    NaN          0      0
# 1    NaN          1      1
# 2    NaN          1      2
# 3    NaN          0      3
# 4    NaN          1      4
# 5    NaN          0      5
# 6    NaN          0      6
# 7    NaN          1      7
# 8    NaN          0      8
# 9    NaN          0      9
# 10   NaN          1     10
# 11   NaN          1     11
# 12   NaN          0     12
# 13   NaN          1     13
# 14   NaN          0     14
# 15   NaN          1     15
# 16   NaN          0     16
# 17   NaN          1     17
# 18   NaN          1     18
# 19   NaN          0     19

# %%
df = pd.DataFrame(data) 
  
df.to_csv('data.csv')

# %%
#Lemmatize all the words.
import nltk

nltk.download('wordnet')
  
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

for i, item in data['Text'].items():
    xyz = ''
    for word in item.split(' '):
        xyz += wordnet_lemmatizer.lemmatize(word)
        xyz += ' '
    if item !=  xyz.strip():
        #print(i, item)
        #print(xyz)
        data['Text'][i] = xyz
data.head(20)
# Out:
# [nltk_data] Downloading package wordnet to /home/pcfic/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-8c3acf202d2e> in <module>()
#       9 for i, item in data['Text'].items():
#      10     xyz = ''
# ---> 11     for word in item.split(' '):
#      12         xyz += wordnet_lemmatizer.lemmatize(word)
#      13         xyz += ' '
#
# AttributeError: 'float' object has no attribute 'split'

# %%
#Tokenize the data.
from nltk.tokenize import sent_tokenize, word_tokenize

data["Text"] = df.apply(lambda row: nltk.word_tokenize(row["Text"]), axis=1)

# %%
data.head(20)
# Out:
#    index Sentiment                                               Text
# 0      0         0             [way, plug, us, unless, go, converter]
# 1      1         1                     [good, case, excellent, value]
# 2      2         1                                   [great, jawbone]
# 3      3         0  [tied, charger, conversations, lasting, minute...
# 4      4         1                                       [mic, great]
# 5      5         0  [jiggle, plug, get, line, right, get, decent, ...
# 6      6         0  [several, dozen, several, hundred, contacts, i...
# 7      7         1                             [razr, owneryou, must]
# 8      8         0                     [needless, say, wasted, money]
# 9      9         0                               [waste, money, time]
# 10    10         1                            [sound, quality, great]
# 11    11         1  [impressed, going, original, battery, extended...
# ...
